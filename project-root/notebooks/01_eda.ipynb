# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 01_EDA.ipynb – Exploratory Data Analysis\n",
    "\n",
    "**Project:** Customer Support Assistant  \n",
    "**Dataset:** Customer Support on Twitter  \n",
    "**Author:** Your Team Name"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1️⃣ Setup & Imports"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "# Set plotting style\n",
    "sns.set(style=\"whitegrid\")\n",
    "plt.rcParams[\"figure.figsize\"] = (10, 6)\n",
    "\n",
    "# Path to data folder\n",
    "DATA_DIR = \"data\""
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2️⃣ Load Data"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Load full dataset if available, else use sample\n",
    "try:\n",
    "    df = pd.read_csv(f\"{DATA_DIR}/twcs.csv\")\n",
    "except FileNotFoundError:\n",
    "    df = pd.read_csv(f\"{DATA_DIR}/sample_dataset.csv\")\n",
    "\n",
    "print(\"Dataset loaded successfully!\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3️⃣ Quick Overview"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Info and basic stats\n",
    "df.info()\n",
    "\n",
    "# Descriptive statistics\n",
    "df.describe(include='all')\n",
    "\n",
    "# Check missing values\n",
    "df.isnull().sum()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4️⃣ Target Distribution"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Inbound vs Outbound tweets\n",
    "sns.countplot(x=\"inbound\", data=df)\n",
    "plt.title(\"Inbound vs Outbound Tweets\")\n",
    "plt.show()\n",
    "\n",
    "# Tweets with Response\n",
    "if \"response_tweet_id\" in df.columns:\n",
    "    df['has_response'] = df['response_tweet_id'].notnull()\n",
    "    sns.countplot(x='has_response', data=df)\n",
    "    plt.title(\"Tweets with Response vs No Response\")\n",
    "    plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5️⃣ Text Analysis"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Text length distribution\n",
    "df['text_length'] = df['text'].str.len()\n",
    "sns.histplot(df['text_length'], bins=50, kde=True)\n",
    "plt.title(\"Tweet Text Length Distribution\")\n",
    "plt.xlabel(\"Number of characters\")\n",
    "plt.ylabel(\"Frequency\")\n",
    "plt.show()\n",
    "\n",
    "# Word count distribution\n",
    "df['word_count'] = df['text'].str.split().apply(len)\n",
    "sns.histplot(df['word_count'], bins=50, kde=True, color='orange')\n",
    "plt.title(\"Tweet Word Count Distribution\")\n",
    "plt.xlabel(\"Number of words\")\n",
    "plt.ylabel(\"Frequency\")\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 6️⃣ Sample Tweets"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Display random sample of tweets\n",
    "df.sample(10)[['text', 'inbound', 'response_tweet_id']]"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 7️⃣ Insights / Next Steps\n",
    "\n",
    "* Most tweets are inbound (customer-to-support) → focus on relevant messages.\n",
    "* Text length varies widely → may require preprocessing (tokenization, padding).\n",
    "* Response availability is imbalanced → consider for classification target.\n",
    "\n",
    "### Optional Enhancements:\n",
    "* Plot distribution by brand/company if available.\n",
    "* Visualize top words or hashtags using `collections.Counter`.\n",
    "* Explore time-based trends if timestamp column exists."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
